# %% [markdown]
# # EJERCICIO 1

# %%
print("Ejercicio 1: suma de los números")
print("--"*20)

numero1 = float(input("Ingrese el primer número: "))
numero2 = float(input("Ingrese el segundo número: "))

suma = numero1 + numero2
#print(f"Resultado: {numero1+numero2}")
print(f"La suma es: {suma}")
# Out:
# Ejercicio 1: suma de los números
# ----------------------------------------
# La suma es: 85.0

# %% [markdown]
# # EJERCICIO 2

# %%
print("Ejercicio 2: Área de un rectángulo")
base = float(input("Ingrese la base del rectángulo: "))
altura = float(input("Ingrese la altura del rectángulo: "))

area = base * altura

#print(f"Resultado: {base*altura}")
print(f"El área del rectángulo es: {area}")
# Out:
# Ejercicio 2: Área de un rectángulo
# El área del rectángulo es: 780.0

# %% [markdown]
# # EJERCICIO 3

# %%
print("Ejercicio 3: Conversión de minutos a horas")
minutos_totales = int(input("Ingrese la cantidad de minutos: "))

horas = minutos_totales // 60
minutos = minutos_totales % 60

print(f"{minutos_totales} minutos equivalen a {horas} horas y {minutos} minutos")
# Out:
# Ejercicio 3: Conversión de minutos a horas
# 80 minutos equivalen a 1 horas y 20 minutos

# %% [markdown]
# # EJERCICIO 4

# %%
print("Ejercicio 3: Precio con descuento")
precio = float(input("Ingrese el precio del producto: "))
producto = float(input("Ingrese el porcentaje de descuento: "))

valor_descuento = precio * (descuento / 100)
precio_final    = precio - valor_descuento

print(f"El precio final a pagar es: {precio_final}")

# %% [markdown]
# # TALLER 1: Ejercicios para resolver

# %% [markdown]
# # EJERCICIO 1

# %%
print("Ejercicio 1: Solicitar el largo y ancho de un terreno y calcular su perímetro")
largo = float(input("Ingrese el largo del terreno: "))
ancho = float(input("Ingrese el ancho del terreno: "))

perimetro = 2 * (largo + ancho)
#perimetro = (2 * largo) + (2 + ancho) Es lo mismo

print(f"El perímetro del terreno es: {perimetro} ")
# Out:
# Ejercicio 1: Solicitar el largo y ancho de un terreno y calcular su perímetro
# El perímetro del terreno es: 6000.0

# %% [markdown]
# # EJERCICIO 2

# %%
print("Ejercicio 2: solicitar tres números y mostrar su promedio")

numero1 = float(input("Ingrese número 1: "))
numero2 = float(input("Ingrese número 2: "))
numero3=  float(input("Ingrese número 3: "))

promedio = (numero1 + numero2 + numero3) / 3

print(f"El promedio de los tres números es: {promedio:.2f}")
# Out:
# Ejercicio 2: solicitar tres números y mostrar su promedio
# El promedio de los tres números es: 5.67

# %% [markdown]
# # EJERCICIO 3

# %%
print("Solicitar el nombre y la edad de una persona y mostrar un mensaje de presentación")
nombre = input("Su nombre es: ")
edad =   input("Ingrese su edad: ")


print(f"Mi nombre es {nombre} y mi edad es {edad}")
# Out:
# Solicitar el nombre y la edad de una persona y mostrar un mensaje de presentación
# Mi nombre es Bel y mi edad es 41

# %% [markdown]
# # EJERCICIO 4

# %%
print("Solicitar un valor en pesos colombianos y mostrar su equivalente aproximado en dólares (tasa fija: 1 USD = 4000 COP)")
pesos = float(input("Ingrese el valor en pesos colombianos: "))
usd = pesos / 4000

print(f"El cambio de pesos colombianos a dólares es: {usd}")
# Out:
# Solicitar un valor en pesos colombianos y mostrar su equivalente aproximado en dólares (tasa fija: 1 USD = 4000 COP)
# El cambio de pesos colombianos a dólares es: 250.0

# %% [markdown]
# # EJERCICIO 5

# %%
print("Solicitar una cantidad de segundos y convertirla a horas, minutos y segundos")

segundos = float(input("Ingrese el número: "))

minutos = segundos / 60
horas = segundos / 3600

print(f"""
Segundos: {segundos}
Minutos: {minutos:.2f} 
Horas: {horas:.2f} 

""")
# Out:
# Solicitar una cantidad de segundos y convertirla a horas, minutos y segundos
# Segundos: 3800.0
# Minutos: 63.33
# Horas: 1.06
